# %% [markdown]
# # Offline Solver

# %%
import os
import pickle
import pandas as pd
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

# %%
os.chdir("..")
import config
from core import osrm

# %% [markdown]
# ## Load Data (Payload) for a single instance

# %%
with open("./data/offline_payload.pkl", 'rb') as f:
    payload = pickle.load(f)

date_str = payload['date']

# %% [markdown]
# ## Offline Functions

# %%
def create_data_model(df_requests, df_driver_runs, date, depot):
    """
    Given a pandas.DataFrame of requests and a pandas.DataFrame of driver runs and the date will
    create the data model for the VRP optimization.

    Args:
        df_requests: (pandas.DataFrame)
        df_driver_runs: (pandas.DataFrame)
        date: (datetime.date or str in isoformat)
        depot: {'lat': , 'lon': }
    Returns:
        dictionary
    Raises:
        TODO
    """
    # generate locations, time_windows, pickups_deliveries, starts, ends, vehicle_capacities
    locations = []  # {'lat': 34, 'lon':- -85.1}
    time_windows = []  # [window_start, window_end]
    pickups_deliveries = []  # [source_location, target_location]
    starts = []  # location_id
    ends = []  # location_id
    am_capacities = []  # 8
    wc_capacities = [] # 3
    am_demands = []
    wc_demands = []
    booking_ids = []
    location_types = []

    current_location = 0
    for k, v in df_driver_runs.iterrows():
        locations.append(depot['pt'])
        locations.append(depot['pt'])
        am_capacities.append(v['am_capacity'])
        wc_capacities.append(v['wc_capacity'])
        time_windows.append([int(v['start_time'])+600, int(v['end_time'])-600])
        time_windows.append([int(v['start_time'])+600, int(v['end_time'])-600])
        starts.append(current_location)
        ends.append(current_location+1)
        booking_ids.append(-1)
        booking_ids.append(-1)
        location_types.append("depot_start")
        location_types.append("depot_end")
        am_demands.append(0)
        am_demands.append(0)
        wc_demands.append(0)
        wc_demands.append(0)
        current_location += 2

    for k, v in df_requests.iterrows():
        locations.append(v['pickup_pt'])
        locations.append(v['dropoff_pt'])
        time_windows.append([int(v['pickup_time_window_start']), int(v['pickup_time_window_end'])])
        time_windows.append([int(v['dropoff_time_window_start']), int(v['dropoff_time_window_end'])])
        pickups_deliveries.append([current_location, current_location+1])
        am_demands.append(v['am'])
        am_demands.append(-v['am'])
        wc_demands.append(v['wc'])
        wc_demands.append(-v['wc'])
        booking_ids.append(v['booking_id'])
        booking_ids.append(v['booking_id'])
        location_types.append("pickup")
        location_types.append("dropoff")
        current_location += 2
    # These functions will need to be created once server is set up
    time_matrix = osrm.request_travel_time_matrix(locations)
    distance_matrix = osrm.request_distance_matrix(locations)

    data = {
        "locations": locations,
        "time_windows": time_windows,
        "pickups_deliveries": pickups_deliveries,
        "starts": starts,
        "ends": ends,
        "am_capacities": am_capacities,
        "wc_capacities": wc_capacities,
        "am_demands": am_demands,
        "wc_demands": wc_demands,
        "booking_ids": booking_ids,
        "location_types": location_types,
        "time_matrix": time_matrix,
        "df_requests": df_requests,
        "df_driver_runs": df_driver_runs,
        "num_vehicles": len(starts),
        "date": date,
        "distance_matrix": distance_matrix
    }
    return data

# %%
def get_sum_of_all_distances(time_matrix, num_vehicles):
    result = 0
    for i in range(num_vehicles*2, len(time_matrix)):
        result += sum(time_matrix[i])
    return result

# %%
def extract_vehicle_runs(data, manager, routing, solution):
    """

    Args:
        data:
        manager:
        routing:
        solution:

    Returns:
        vehicle_run (list)
    """
    print(f'VRP: extract_vehicle_runs - Start')
    print(f"Objective: {solution.ObjectiveValue()}")
    time_dimension = routing.GetDimensionOrDie('Time')
    distance_dimension = routing.GetDimensionOrDie('Distance')
    total_time = 0
    vehicle_runs = []
    plan_outputs = []
    for vehicle_id in range(data['num_vehicles']):
        vehicle_cost = 0
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        vehicle_run = []
        i = 0
        while not routing.IsEnd(index):
            time_var = time_dimension.CumulVar(index)
            plan_output += '{0} Time({1},{2}) -> '.format(
                manager.IndexToNode(index), solution.Min(time_var),
                solution.Max(time_var))
            vehicle_run.append({'loc': manager.IndexToNode(index),
                                'early_time': solution.Min(time_var),
                                'late_time': solution.Max(time_var),
                                'order': i})
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            cost = routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
            vehicle_cost += cost
            i += 1
        time_var = time_dimension.CumulVar(index)
        vehicle_run.append({'loc': manager.IndexToNode(index),
                            'early_time': solution.Min(time_var),
                            'late_time': solution.Max(time_var),
                            'order': i})
        vehicle_runs.append(vehicle_run)
        plan_output += '{0} Time({1},{2})\n'.format(manager.IndexToNode(index),
                                                    solution.Min(time_var),
                                                    solution.Max(time_var))
        plan_output += 'Time of the route: {} seconds\n'.format(
            solution.Min(time_var))
        plan_output += f"Total Cost = {vehicle_cost}"
        plan_outputs.append(plan_output)
        print(f"plan_output for vehicle_id={vehicle_id}: {plan_output}")
        total_time += solution.Min(time_var)
        print(f'VRP: extract_vehicle_runs - End')
        
    return vehicle_runs

# %%
def prepare_manifests(data, vehicle_runs):
    print(f'VRP: prepare_manifests - Start')
    dfs = []
    for i in range(len(vehicle_runs)):
        vehicle_run = vehicle_runs[i]
        df = pd.DataFrame.from_records(vehicle_run)
        df['run_id'] = i
        dfs.append(df)
    result = pd.concat(dfs, ignore_index=True)
    temp = pd.DataFrame({'booking_id': data['booking_ids'],'action': data['location_types']})
    result = result.merge(temp, how='left', left_on='loc', right_index=True, validate='one_to_one')
    result['early_arrival_dt'] = result['early_time']
    result['scheduled_arrival_dt'] = result['late_time']
    result['state'] = "planned"
    if type(data['date']) == str:
        result['date'] = data['date']
    else:
        result['date'] = data['date'].isoformat()
    result['early_arrival_dt'] = result['scheduled_arrival_dt']
    result = result[['run_id', 'booking_id', 'order', 'early_arrival_dt', 'state','action', 'date']]
    return result

# %%
def run_vrp(data):
    """
    Given a data model generated by optimizer.create_data_model, will run a VRP. Returns the timetable
    as a pandas.DataFrame from this VRP run.

    Args:
        data: (dictionary)
    Returns:
        (pandas.DataFrame)
    Raises:
        TODO
    """
    print(f'VRP: Running VRP to return a Timetable')
    if config.VRP_TIME_LIMIT is None:
        print(f'VRP: Time Limit is None')
        vrp_time_limit = len(data['pickups_deliveries'])
    else:
        vrp_time_limit = config.VRP_TIME_LIMIT
        print(f'VRP: Time Limit is {vrp_time_limit}')
    print(f'VRP: time limit will be {vrp_time_limit}')

    # Create the routing index manager
    print(f'VRP: Create Routing Index Manager (pywrapcp.RoutingIndexManager) - Start')
    manager = pywrapcp.RoutingIndexManager(len(data['time_matrix']),
                                           data['num_vehicles'],
                                           data['starts'],
                                           data['ends'])
    print("VRP: Created Routing Index Manager")
    # Create routing model
    print(f'VRP: Creating Routing Model (pywrapcp.RoutingModel) - Start')
    routing = pywrapcp.RoutingModel(manager)
    print("VRP: Created Routing Model")

    max_distance_per_vehicle = get_sum_of_all_distances(data['distance_matrix'], data['num_vehicles'])
    max_time_per_vehicle = get_sum_of_all_distances(data['time_matrix'], data['num_vehicles'])

    # DISTANCE dimension
    def distance_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    distance_callback_index = routing.RegisterTransitCallback(distance_callback)
    dimension_name = 'Distance'
    print(f'VRP: Adding Distance Dimension (routing.AddDimension) - Start')
    routing.AddDimension(
        distance_callback_index,
        0,  # slack TODO
        max_distance_per_vehicle,  # max distance per vehicle
        True,  # start cumul to zero
        dimension_name)
    # distance_dimension = routing.GetDimensionOrDie(dimension_name)
    print("VRP: Added Distance Dimension")

    # TIME dimension
    def time_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['time_matrix'][from_node][to_node] + config.DWELL_TIME

    transit_callback_index = routing.RegisterTransitCallback(time_callback)
    dimension_name = 'Time'
    print(f'VRP: Adding Time Dimension (routing.AddDimension) - Start')
    routing.AddDimension(
        transit_callback_index,
        config.MAX_VEHICLE_SLACK,  # slack TODO
        config.DAY_END_TIME,  # max time per vehicle
        False,  # start cumul to zero
        dimension_name)
    time_dimension = routing.GetDimensionOrDie(dimension_name)

    print("VRP: Added Time Dimension")

    # set objective
    print(f'VRP: SetArcCostEvalatorOfAllVehicles')
    if config.OBJECTIVE_IS_DISTANCE:
        routing.SetArcCostEvaluatorOfAllVehicles(distance_callback_index)
    else:
        routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    print("VRP: Defined Transit Callback")

    # pickup and deliveries.
    print(f'VRP: Adding Pickup/Delivery indexes for each request - Start')
    for request in data['pickups_deliveries']:
        pickup_index = manager.NodeToIndex(request[0])
        delivery_index = manager.NodeToIndex(request[1])
        routing.AddPickupAndDelivery(pickup_index, delivery_index)
        routing.solver().Add(
            routing.VehicleVar(pickup_index) == routing.VehicleVar(
                delivery_index))
        routing.solver().Add(
            time_dimension.CumulVar(pickup_index) <=
            time_dimension.CumulVar(delivery_index))

    print("VRP: Finished with Pickup & Deliveries")

    # time windows (trips)
    print("VRP: Adding Time Windows - Start")
    for time_window_index in range(0, len(data['time_windows'])):
        if (time_window_index in data['starts'] + data['ends']):
            continue
        index = manager.NodeToIndex(time_window_index)
        v = data['time_windows'][time_window_index]
        time_dimension.CumulVar(index).SetRange(v[0], v[1])

    print("VRP: Completed Time Windows")

    # time windows (start and end locations)
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        start_loc = data['starts'][vehicle_id]
        time_dimension.CumulVar(index).SetRange(
            data['time_windows'][start_loc][0],
            data['time_windows'][start_loc][1])
        index = routing.End(vehicle_id)
        end_loc = data['ends'][vehicle_id]
        time_dimension.CumulVar(index).SetRange(
            data['time_windows'][end_loc][0],
            data['time_windows'][end_loc][1])
    print("VRP: Completed Time Windows (Start and End Locations)")


    # Instantiate route start and end times to produce feasible times.
    print("VRP: Instantiate Route Start and End Times - Start")
    for i in range(data['num_vehicles']):
        routing.AddVariableMinimizedByFinalizer(
            time_dimension.CumulVar(routing.Start(i)))
        routing.AddVariableMinimizedByFinalizer(
            time_dimension.CumulVar(routing.End(i)))

    print("VRP: Instantiated Route Start and End Times")

    # AM demand constraints
    def am_demand_callback(from_index):
        from_node = manager.IndexToNode(from_index)
        return data['am_demands'][from_node]
    print(f'VRP: am_demand_callback - Starting')
    am_demand_callback_index = routing.RegisterUnaryTransitCallback(
        am_demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        am_demand_callback_index,
        0,  # null capacity slack
        data['am_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'AMCapacity')

    print("VRP: Complete AM Capacity Constraints")

    # WC demand constraints
    def wc_demand_callback(from_index):
        from_node = manager.IndexToNode(from_index)
        return data['wc_demands'][from_node]

    print(f'VRP: Starting wc_demand_callback')
    wc_demand_callback_index = routing.RegisterUnaryTransitCallback(
        wc_demand_callback)
    print(f'VRP: Ended wc_demand_callback')
    routing.AddDimensionWithVehicleCapacity(
        wc_demand_callback_index,
        0,  # null capacity slack
        data['wc_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'WCCapacity')

    print("VRP: Completed Capacity Constraints")

    # Allow to drop nodes
    if config.OBJECTIVE_IS_DISTANCE:
        penalty = max_distance_per_vehicle
    else:
        penalty = max_time_per_vehicle
    print(f"VRP Penalty={penalty}")
    for node in range(data['num_vehicles'] * 2, len(data['time_matrix'])):
        routing.AddDisjunction([manager.NodeToIndex(node)], penalty)

    print("VRP: Completed Allowing to Drop Nodes")

    # search parameters
    print(f'VRP: Assigning Search Parameters (pywrapcp.DefaultRoutingSearchParameters)')
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        config.FIRST_SOLUTION_STRATEGY)
    search_parameters.local_search_metaheuristic = (
        config.LOCAL_SEARCH_METAHEURISTIC)
    search_parameters.time_limit.seconds = vrp_time_limit

    print("VRP: Completed Search Parameters")
    

    # Solve the problem.
    print("VRP: Get Solution (routing.SolveWithParameters) - Start")
    search_parameters.log_search = config.LOG_SEARCH
    solution = routing.SolveWithParameters(search_parameters)

    print("VRP: Extract Veh. Runs & Manifests from Solution")
    vehicle_runs = extract_vehicle_runs(data, manager, routing, solution)
    manifests = prepare_manifests(data, vehicle_runs)
    return manifests

# %%
def offline_solver(payload):
    """
    Will solve with ORTOOLS.

    Args:
        payload: (JSON) see prepare_data_for_offline_solver()

    Returns:
        (JSON) resulting manifests for this date

    """
    data = create_data_model(pd.DataFrame.from_records(payload['requests']), pd.DataFrame.from_records(payload['driver_runs']), payload['date'], payload['depot'])
    df_manifests = run_vrp(data)
    df_manifests = df_manifests[df_manifests['booking_id'] != -1]
    df_requests = pd.DataFrame.from_records(payload['requests'])
    df_manifests = df_manifests.merge(df_requests, how='left', on='booking_id')
    df_manifests['time_window_start'] = df_manifests.apply(lambda row: row['pickup_time_window_start'] if (row['action'] == 'pickup') else row['dropoff_time_window_start'], axis=1)
    df_manifests['time_window_end'] = df_manifests.apply(lambda row: row['pickup_time_window_end'] if (row['action'] == 'pickup') else row['dropoff_time_window_end'], axis=1)
    df_manifests['node_id'] = df_manifests.apply(lambda row: row['pickup_node_id'] if (row['action'] == 'pickup') else row['dropoff_node_id'], axis=1)
    dfs = []
    for run_id in df_manifests['run_id'].unique():
        df_manifest = df_manifests[(df_manifests['run_id']==run_id)].sort_values(by='order', ascending=True)
        current_location = df_manifest.iloc[0]
        current_scheduled_time_tw = current_location['time_window_start']
        current_scheduled_time_d = list(filter(lambda x: x['run_id']==run_id, payload['driver_runs']))[0]['start_time'] + payload['time_matrix'][payload['depot']['node_id']][current_location['node_id']] + config.DWELL_TIME
        current_scheduled_time = max(current_scheduled_time_d, current_scheduled_time_tw)
        scheduled_times = [current_scheduled_time]
        for i in range(1, len(df_manifest)):
            current_location = df_manifest.iloc[i-1]
            next_location = df_manifest.iloc[i]
            current_scheduled_time = current_scheduled_time + payload['time_matrix'][current_location['node_id']][next_location['node_id']] + config.DWELL_TIME
            if current_scheduled_time < next_location['time_window_start']:
                current_scheduled_time = next_location['time_window_start']
            scheduled_times.append(current_scheduled_time)
        df_manifest['scheduled_time'] = scheduled_times
        dfs.append(df_manifest)
    df = pd.concat(dfs, ignore_index=True)
    return df[['run_id', 'booking_id', 'action', 'scheduled_time', 'node_id']].to_dict('records')

# %% [markdown]
# ### Run Offline Solver

# %%
manifests = offline_solver(payload)
# Out:
# VRP: Running VRP to return a Timetable
# VRP: Time Limit is 300
# VRP: time limit will be 300
# VRP: Create Routing Index Manager (pywrapcp.RoutingIndexManager) - Start
# VRP: Created Routing Index Manager
# VRP: Creating Routing Model (pywrapcp.RoutingModel) - Start
# VRP: Created Routing Model
# VRP: Adding Distance Dimension (routing.AddDimension) - Start
# VRP: Added Distance Dimension
# VRP: Adding Time Dimension (routing.AddDimension) - Start
# VRP: Added Time Dimension
# VRP: SetArcCostEvalatorOfAllVehicles
# VRP: Defined Transit Callback
# VRP: Adding Pickup/Delivery indexes for each request - Start
# VRP: Finished with Pickup & Deliveries
# VRP: Adding Time Windows - Start
# VRP: Completed Time Windows
# VRP: Completed Time Windows (Start and End Locations)
# VRP: Instantiate Route Start and End Times - Start
# VRP: Instantiated Route Start and End Times
# VRP: am_demand_callback - Starting
# VRP: Complete AM Capacity Constraints
# VRP: Starting wc_demand_callback
# VRP: Ended wc_demand_callback
# VRP: Completed Capacity Constraints
# VRP Penalty=1451734033
# VRP: Completed Allowing to Drop Nodes
# VRP: Assigning Search Parameters (pywrapcp.DefaultRoutingSearchParameters)
# VRP: Completed Search Parameters
# VRP: Get Solution (routing.SolveWithParameters) - Start
# VRP: Extract Veh. Runs & Manifests from Solution
# VRP: extract_vehicle_runs - Start
# Objective: 2092909
# plan_output for vehicle_id=0: Route for vehicle 0:
# 0 Time(15000,15000) -> 40 Time(19800,19836) -> 36 Time(20419,20455) -> 37 Time(20953,20989) -> 41 Time(21253,22082) -> 58 Time(27000,27666) -> 59 Time(27639,28305) -> 84 Time(28800,29036) -> 72 Time(29464,29700) -> 73 Time(30361,30624) -> 85 Time(30661,31847) -> 114 Time(32400,32639) -> 116 Time(33584,33823) -> 117 Time(33942,34181) -> 134 Time(34567,35167) -> 115 Time(35093,35693) -> 135 Time(35961,36561) -> 162 Time(37062,37662) -> 156 Time(37566,38166) -> 163 Time(38107,38707) -> 157 Time(38960,39560) -> 174 Time(39752,40590) -> 175 Time(40545,41383) -> 186 Time(42300,42436) -> 190 Time(43200,43200) -> 187 Time(43633,43633) -> 200 Time(43934,43934) -> 191 Time(44442,44442) -> 201 Time(45664,45664) -> 212 Time(46045,46045) -> 206 Time(46683,46683) -> 213 Time(47508,47508) -> 236 Time(48384,48384) -> 207 Time(48862,48862) -> 237 Time(49565,49565) -> 1 Time(50070,50070)
# Time of the route: 50070 seconds
# Total Cost = 173271
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=1: Route for vehicle 1:
# 2 Time(15000,15000) -> 46 Time(22500,22555) -> 44 Time(23413,23468) -> 45 Time(24135,24190) -> 48 Time(24581,24636) -> 49 Time(25089,25144) -> 47 Time(25553,26348) -> 60 Time(27000,27506) -> 74 Time(27900,28310) -> 61 Time(28810,29220) -> 75 Time(29580,30118) -> 112 Time(30600,30987) -> 106 Time(31367,31754) -> 113 Time(31786,32173) -> 107 Time(32461,32848) -> 242 Time(48600,48995) -> 250 Time(49500,49513) -> 266 Time(50400,50400) -> 243 Time(50797,50797) -> 267 Time(51455,51455) -> 251 Time(52023,52023) -> 3 Time(52407,52407)
# Time of the route: 52407 seconds
# Total Cost = 101634
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=2: Route for vehicle 2:
# 4 Time(18600,18600) -> 42 Time(21600,22827) -> 43 Time(22527,23754) -> 50 Time(23658,24885) -> 51 Time(24099,25326) -> 78 Time(27900,28694) -> 86 Time(28800,29572) -> 100 Time(29700,30186) -> 79 Time(30784,31270) -> 87 Time(31275,31894) -> 101 Time(31807,33028) -> 132 Time(34200,35593) -> 142 Time(36000,36189) -> 133 Time(36993,37182) -> 143 Time(37694,39218) -> 240 Time(48600,48600) -> 228 Time(49050,49050) -> 229 Time(49671,49671) -> 241 Time(50733,50733) -> 262 Time(51505,51505) -> 263 Time(52477,52477) -> 5 Time(53309,53309)
# Time of the route: 53309 seconds
# Total Cost = 133293
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=3: Route for vehicle 3:
# 6 Time(18600,18600) -> 38 Time(19985,21600) -> 39 Time(21010,22748) -> 52 Time(26100,26909) -> 53 Time(27037,27846) -> 80 Time(27982,28791) -> 82 Time(28887,29696) -> 81 Time(30012,30821) -> 83 Time(30583,32237) -> 138 Time(35100,35517) -> 139 Time(35712,36129) -> 140 Time(36483,36900) -> 141 Time(38067,38964) -> 194 Time(43200,43200) -> 195 Time(44872,44872) -> 7 Time(45299,45299)
# Time of the route: 45299 seconds
# Total Cost = 135127
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=4: Route for vehicle 4:
# 8 Time(25800,25800) -> 148 Time(36000,36505) -> 166 Time(37200,37309) -> 168 Time(37951,38060) -> 149 Time(38367,38476) -> 167 Time(38667,39383) -> 169 Time(38967,39683) -> 180 Time(41400,42231) -> 182 Time(41700,42531) -> 181 Time(42230,43061) -> 183 Time(42852,43683) -> 220 Time(46800,47155) -> 221 Time(47243,47598) -> 232 Time(47855,48210) -> 226 Time(48242,48597) -> 227 Time(49077,49432) -> 233 Time(49765,50120) -> 286 Time(52560,52560) -> 284 Time(52860,52860) -> 285 Time(53278,53278) -> 287 Time(54028,54028) -> 308 Time(54705,54705) -> 309 Time(55152,55152) -> 9 Time(55600,55600)
# Time of the route: 55600 seconds
# Total Cost = 59270
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=5: Route for vehicle 5:
# 10 Time(25800,25800) -> 54 Time(26747,26892) -> 55 Time(27916,28061) -> 68 Time(28520,28665) -> 69 Time(29200,29345) -> 94 Time(29915,30061) -> 104 Time(30948,31094) -> 95 Time(31795,31941) -> 105 Time(32674,32911) -> 126 Time(33478,33715) -> 130 Time(35209,35446) -> 127 Time(36040,36277) -> 146 Time(36340,36577) -> 131 Time(37256,37493) -> 147 Time(38336,39367) -> 176 Time(39600,41133) -> 177 Time(40105,41638) -> 210 Time(45900,47560) -> 211 Time(46574,48234) -> 252 Time(49500,50159) -> 246 Time(49971,50630) -> 247 Time(51129,51788) -> 253 Time(52036,52695) -> 316 Time(55800,55800) -> 314 Time(56100,56100) -> 317 Time(57539,57539) -> 315 Time(57956,57956) -> 332 Time(58750,58750) -> 333 Time(59262,59262) -> 11 Time(59928,59928)
# Time of the route: 59928 seconds
# Total Cost = 192220
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=6: Route for vehicle 6:
# 12 Time(25800,25800) -> 62 Time(27000,27040) -> 70 Time(27686,27726) -> 64 Time(28136,28176) -> 63 Time(28941,28981) -> 65 Time(29528,29568) -> 71 Time(30254,30294) -> 118 Time(33300,33304) -> 124 Time(34083,34087) -> 119 Time(34834,34838) -> 125 Time(35744,35748) -> 144 Time(36533,36537) -> 158 Time(37254,37258) -> 159 Time(37897,37901) -> 145 Time(38477,38481) -> 178 Time(40500,41462) -> 184 Time(41400,42360) -> 179 Time(42027,42987) -> 185 Time(43069,44029) -> 196 Time(43792,44752) -> 202 Time(45000,45340) -> 197 Time(45738,46078) -> 203 Time(46233,47483) -> 214 Time(46533,48161) -> 215 Time(47208,48836) -> 254 Time(49500,50641) -> 248 Time(49800,50941) -> 249 Time(50670,51811) -> 255 Time(51239,52380) -> 288 Time(53100,53406) -> 282 Time(53590,53896) -> 283 Time(54312,54618) -> 289 Time(54887,55220) -> 298 Time(55439,55772) -> 299 Time(56262,56595) -> 326 Time(57600,58098) -> 334 Time(58500,58500) -> 327 Time(59412,59412) -> 335 Time(59873,59873) -> 348 Time(60849,60849) -> 350 Time(61149,61149) -> 349 Time(61864,61864) -> 351 Time(62718,62718) -> 13 Time(63584,63584)
# Time of the route: 63584 seconds
# Total Cost = 226353
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=7: Route for vehicle 7:
# 14 Time(25800,25800) -> 90 Time(28800,29225) -> 102 Time(30550,30975) -> 91 Time(31522,31947) -> 103 Time(32052,32477) -> 150 Time(36000,37740) -> 151 Time(36780,38520) -> 188 Time(42300,43902) -> 189 Time(42897,44499) -> 268 Time(50400,50948) -> 278 Time(51300,51416) -> 269 Time(51757,51873) -> 279 Time(53112,53228) -> 300 Time(54013,54129) -> 292 Time(54784,54900) -> 293 Time(55822,56071) -> 301 Time(56782,57174) -> 330 Time(58500,58500) -> 346 Time(59498,59498) -> 347 Time(60113,60113) -> 331 Time(60829,60829) -> 352 Time(61448,61448) -> 353 Time(62225,62225) -> 15 Time(62902,62902)
# Time of the route: 62902 seconds
# Total Cost = 152588
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=8: Route for vehicle 8:
# 16 Time(25800,25800) -> 92 Time(28800,28847) -> 76 Time(29359,29406) -> 77 Time(29827,29874) -> 93 Time(30797,31472) -> 108 Time(31638,32313) -> 109 Time(32382,33057) -> 120 Time(33358,35010) -> 121 Time(34099,35751) -> 154 Time(36000,37713) -> 155 Time(36744,38457) -> 170 Time(37800,39276) -> 171 Time(38229,39705) -> 198 Time(43200,43948) -> 192 Time(44129,44877) -> 199 Time(45021,45769) -> 193 Time(45982,46730) -> 208 Time(46632,47380) -> 209 Time(47495,48243) -> 224 Time(48152,48900) -> 225 Time(49156,50012) -> 272 Time(50400,50860) -> 276 Time(51300,51389) -> 260 Time(51671,51760) -> 277 Time(52049,52138) -> 261 Time(52647,52736) -> 273 Time(53591,53796) -> 302 Time(54309,55800) -> 303 Time(55589,57139) -> 324 Time(57600,57973) -> 325 Time(58355,58728) -> 338 Time(59400,59400) -> 344 Time(60068,60068) -> 345 Time(61109,61109) -> 354 Time(61812,61812) -> 339 Time(62699,62699) -> 355 Time(63627,63627) -> 17 Time(64160,64160)
# Time of the route: 64160 seconds
# Total Cost = 225947
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=9: Route for vehicle 9:
# 18 Time(25800,25800) -> 66 Time(27000,27020) -> 56 Time(27557,27577) -> 67 Time(28376,28396) -> 57 Time(28689,28709) -> 110 Time(30600,30687) -> 96 Time(31413,31500) -> 111 Time(32283,32372) -> 97 Time(33189,33278) -> 136 Time(34800,35205) -> 137 Time(35327,35732) -> 152 Time(36236,36641) -> 160 Time(37872,38277) -> 153 Time(39016,39421) -> 161 Time(39518,40398) -> 216 Time(46800,47372) -> 230 Time(47700,47746) -> 217 Time(48074,48120) -> 244 Time(48600,48611) -> 231 Time(49075,49086) -> 245 Time(49738,49749) -> 258 Time(50466,50477) -> 256 Time(51040,51051) -> 257 Time(51738,51749) -> 259 Time(52824,52835) -> 290 Time(53731,53742) -> 306 Time(54851,54862) -> 291 Time(55569,55580) -> 307 Time(56154,56165) -> 322 Time(56700,56700) -> 323 Time(57273,57273) -> 328 Time(58277,58277) -> 329 Time(59021,59021) -> 340 Time(59623,59623) -> 342 Time(60631,60631) -> 343 Time(61975,61975) -> 341 Time(62834,62834) -> 19 Time(63910,63910)
# Time of the route: 63910 seconds
# Total Cost = 248942
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=10: Route for vehicle 10:
# 20 Time(54600,54600) -> 318 Time(55800,56828) -> 320 Time(56486,57514) -> 321 Time(57095,58123) -> 319 Time(58070,59098) -> 356 Time(63900,64900) -> 357 Time(64934,65934) -> 360 Time(66000,67000) -> 358 Time(66300,67300) -> 359 Time(67510,68510) -> 361 Time(68710,69710) -> 362 Time(72000,72807) -> 364 Time(72900,73703) -> 365 Time(73722,74525) -> 363 Time(74921,75724) -> 370 Time(76500,76500) -> 371 Time(77498,77498) -> 21 Time(78569,78569)
# Time of the route: 78569 seconds
# Total Cost = 161535
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=11: Route for vehicle 11:
# 22 Time(43800,43800) -> 222 Time(46800,48600) -> 223 Time(47784,49677) -> 238 Time(48600,50400) -> 239 Time(49548,51414) -> 274 Time(51300,52399) -> 275 Time(52641,53740) -> 296 Time(54000,54676) -> 304 Time(54640,55316) -> 305 Time(54979,55655) -> 297 Time(55455,56131) -> 336 Time(59400,60884) -> 337 Time(59839,61323) -> 366 Time(72900,74523) -> 367 Time(73525,75148) -> 368 Time(76500,76500) -> 369 Time(77110,77110) -> 372 Time(77410,77410) -> 373 Time(77965,77965) -> 23 Time(79262,79262)
# Time of the route: 79262 seconds
# Total Cost = 114166
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=12: Route for vehicle 12:
# 24 Time(25800,25800) -> 98 Time(29700,30035) -> 88 Time(30143,30478) -> 89 Time(30841,31176) -> 99 Time(31536,32451) -> 128 Time(33300,34105) -> 122 Time(34253,35058) -> 123 Time(35058,35863) -> 129 Time(35767,36849) -> 172 Time(37800,37968) -> 164 Time(38532,38700) -> 165 Time(39747,40181) -> 173 Time(40047,41069) -> 204 Time(45000,45163) -> 205 Time(46218,46381) -> 218 Time(46946,47109) -> 234 Time(47753,47916) -> 235 Time(48221,48384) -> 219 Time(49254,49417) -> 264 Time(50400,50493) -> 270 Time(51437,51530) -> 271 Time(52002,52095) -> 280 Time(52630,52723) -> 281 Time(53272,53365) -> 265 Time(54046,54139) -> 294 Time(54346,54439) -> 295 Time(55184,55277) -> 312 Time(55800,55800) -> 310 Time(56262,56262) -> 313 Time(56816,56816) -> 311 Time(57541,57541) -> 25 Time(58089,58089)
# Time of the route: 58089 seconds
# Total Cost = 168563
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=13: Route for vehicle 13:
# 26 Time(25800,25800) -> 27 Time(26100,26100)
# Time of the route: 26100 seconds
# Total Cost = 0
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=14: Route for vehicle 14:
# 28 Time(25800,25800) -> 29 Time(26100,26100)
# Time of the route: 26100 seconds
# Total Cost = 0
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=15: Route for vehicle 15:
# 30 Time(25800,25800) -> 31 Time(26100,26100)
# Time of the route: 26100 seconds
# Total Cost = 0
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=16: Route for vehicle 16:
# 32 Time(25800,25800) -> 33 Time(26100,26100)
# Time of the route: 26100 seconds
# Total Cost = 0
# VRP: extract_vehicle_runs - End
# plan_output for vehicle_id=17: Route for vehicle 17:
# 34 Time(25800,25800) -> 35 Time(26100,26100)
# Time of the route: 26100 seconds
# Total Cost = 0
# VRP: extract_vehicle_runs - End
# VRP: prepare_manifests - Start

# %%
manifests
# Out:
# [{'run_id': 0,
#   'booking_id': 1129912,
#   'action': 'pickup',
#   'scheduled_time': 19800,
#   'node_id': 5},
#  {'run_id': 0,
#   'booking_id': 1129871,
#   'action': 'pickup',
#   'scheduled_time': 20419,
#   'node_id': 1},
#  {'run_id': 0,
#   'booking_id': 1129871,
#   'action': 'dropoff',
#   'scheduled_time': 20953,
#   'node_id': 2},
#  {'run_id': 0,
#   'booking_id': 1129912,
#   'action': 'dropoff',
#   'scheduled_time': 21253,
#   'node_id': 6},
#  {'run_id': 0,
#   'booking_id': 1126925,
#   'action': 'pickup',
#   'scheduled_time': 27000,
#   'node_id': 23},
#  {'run_id': 0,
#   'booking_id': 1126925,
#   'action': 'dropoff',
#   'scheduled_time': 27639,
#   'node_id': 24},
#  {'run_id': 0,
#   'booking_id': 1128512,
#   'action': 'pickup',
#   'scheduled_time': 28800,
#   'node_id': 49},
#  {'run_id': 0,
#   'booking_id': 1130181,
#   'action': 'pickup',
#   'scheduled_time': 29464,
#   'node_id': 37},
#  {'run_id': 0,
#   'booking_id': 1130181,
#   'action': 'dropoff',
#   'scheduled_time': 30361,
#   'node_id': 38},
#  {'run_id': 0,
#   'booking_id': 1128512,
#   'action': 'dropoff',
#   'scheduled_time': 30661,
#   'node_id': 50},
#  {'run_id': 0,
#   'booking_id': 1129877,
#   'action': 'pickup',
#   'scheduled_time': 32400,
#   'node_id': 79},
#  {'run_id': 0,
#   'booking_id': 1130646,
#   'action': 'pickup',
#   'scheduled_time': 33584,
#   'node_id': 81},
#  {'run_id': 0,
#   'booking_id': 1130646,
#   'action': 'dropoff',
#   'scheduled_time': 33942,
#   'node_id': 82},
#  {'run_id': 0,
#   'booking_id': 1130238,
#   'action': 'pickup',
#   'scheduled_time': 34567,
#   'node_id': 99},
#  {'run_id': 0,
#   'booking_id': 1129877,
#   'action': 'dropoff',
#   'scheduled_time': 35093,
#   'node_id': 80},
#  {'run_id': 0,
#   'booking_id': 1130238,
#   'action': 'dropoff',
#   'scheduled_time': 35961,
#   'node_id': 100},
#  {'run_id': 0,
#   'booking_id': 1130171,
#   'action': 'pickup',
#   'scheduled_time': 37062,
#   'node_id': 127},
#  {'run_id': 0,
#   'booking_id': 1132312,
#   'action': 'pickup',
#   'scheduled_time': 37566,
#   'node_id': 121},
#  {'run_id': 0,
#   'booking_id': 1130171,
#   'action': 'dropoff',
#   'scheduled_time': 38107,
#   'node_id': 128},
#  {'run_id': 0,
#   'booking_id': 1132312,
#   'action': 'dropoff',
#   'scheduled_time': 38960,
#   'node_id': 122},
#  {'run_id': 0,
#   'booking_id': 1130233,
#   'action': 'pickup',
#   'scheduled_time': 39752,
#   'node_id': 139},
#  {'run_id': 0,
#   'booking_id': 1130233,
#   'action': 'dropoff',
#   'scheduled_time': 40545,
#   'node_id': 140},
#  {'run_id': 0,
#   'booking_id': 1130210,
#   'action': 'pickup',
#   'scheduled_time': 42300,
#   'node_id': 151},
#  {'run_id': 0,
#   'booking_id': 1129865,
#   'action': 'pickup',
#   'scheduled_time': 43200,
#   'node_id': 155},
#  {'run_id': 0,
#   'booking_id': 1130210,
#   'action': 'dropoff',
#   'scheduled_time': 43633,
#   'node_id': 152},
#  {'run_id': 0,
#   'booking_id': 1132313,
#   'action': 'pickup',
#   'scheduled_time': 43934,
#   'node_id': 165},
#  {'run_id': 0,
#   'booking_id': 1129865,
#   'action': 'dropoff',
#   'scheduled_time': 44442,
#   'node_id': 156},
#  {'run_id': 0,
#   'booking_id': 1132313,
#   'action': 'dropoff',
#   'scheduled_time': 45664,
#   'node_id': 166},
#  {'run_id': 0,
#   'booking_id': 1129921,
#   'action': 'pickup',
#   'scheduled_time': 46045,
#   'node_id': 177},
#  {'run_id': 0,
#   'booking_id': 1130225,
#   'action': 'pickup',
#   'scheduled_time': 46683,
#   'node_id': 171},
#  {'run_id': 0,
#   'booking_id': 1129921,
#   'action': 'dropoff',
#   'scheduled_time': 47508,
#   'node_id': 178},
#  {'run_id': 0,
#   'booking_id': 1130211,
#   'action': 'pickup',
#   'scheduled_time': 48384,
#   'node_id': 201},
#  {'run_id': 0,
#   'booking_id': 1130225,
#   'action': 'dropoff',
#   'scheduled_time': 48862,
#   'node_id': 172},
#  {'run_id': 0,
#   'booking_id': 1130211,
#   'action': 'dropoff',
#   'scheduled_time': 49565,
#   'node_id': 202},
#  {'run_id': 1,
#   'booking_id': 1129900,
#   'action': 'pickup',
#   'scheduled_time': 22500,
#   'node_id': 11},
#  {'run_id': 1,
#   'booking_id': 1129828,
#   'action': 'pickup',
#   'scheduled_time': 23413,
#   'node_id': 9},
#  {'run_id': 1,
#   'booking_id': 1129828,
#   'action': 'dropoff',
#   'scheduled_time': 24135,
#   'node_id': 10},
#  {'run_id': 1,
#   'booking_id': 1129924,
#   'action': 'pickup',
#   'scheduled_time': 24581,
#   'node_id': 13},
#  {'run_id': 1,
#   'booking_id': 1129924,
#   'action': 'dropoff',
#   'scheduled_time': 25089,
#   'node_id': 14},
#  {'run_id': 1,
#   'booking_id': 1129900,
#   'action': 'dropoff',
#   'scheduled_time': 25553,
#   'node_id': 12},
#  {'run_id': 1,
#   'booking_id': 1129833,
#   'action': 'pickup',
#   'scheduled_time': 27000,
#   'node_id': 25},
#  {'run_id': 1,
#   'booking_id': 1129928,
#   'action': 'pickup',
#   'scheduled_time': 27900,
#   'node_id': 39},
#  {'run_id': 1,
#   'booking_id': 1129833,
#   'action': 'dropoff',
#   'scheduled_time': 28810,
#   'node_id': 26},
#  {'run_id': 1,
#   'booking_id': 1129928,
#   'action': 'dropoff',
#   'scheduled_time': 29580,
#   'node_id': 40},
#  {'run_id': 1,
#   'booking_id': 1130246,
#   'action': 'pickup',
#   'scheduled_time': 30600,
#   'node_id': 77},
#  {'run_id': 1,
#   'booking_id': 1129864,
#   'action': 'pickup',
#   'scheduled_time': 31367,
#   'node_id': 71},
#  {'run_id': 1,
#   'booking_id': 1130246,
#   'action': 'dropoff',
#   'scheduled_time': 31786,
#   'node_id': 78},
#  {'run_id': 1,
#   'booking_id': 1129864,
#   'action': 'dropoff',
#   'scheduled_time': 32461,
#   'node_id': 72},
#  {'run_id': 1,
#   'booking_id': 1129930,
#   'action': 'pickup',
#   'scheduled_time': 48600,
#   'node_id': 207},
#  {'run_id': 1,
#   'booking_id': 1131501,
#   'action': 'pickup',
#   'scheduled_time': 49500,
#   'node_id': 215},
#  {'run_id': 1,
#   'booking_id': 1130172,
#   'action': 'pickup',
#   'scheduled_time': 50400,
#   'node_id': 231},
#  {'run_id': 1,
#   'booking_id': 1129930,
#   'action': 'dropoff',
#   'scheduled_time': 50797,
#   'node_id': 208},
#  {'run_id': 1,
#   'booking_id': 1130172,
#   'action': 'dropoff',
#   'scheduled_time': 51455,
#   'node_id': 232},
#  {'run_id': 1,
#   'booking_id': 1131501,
#   'action': 'dropoff',
#   'scheduled_time': 52023,
#   'node_id': 216},
#  {'run_id': 2,
#   'booking_id': 1132038,
#   'action': 'pickup',
#   'scheduled_time': 21600,
#   'node_id': 7},
#  {'run_id': 2,
#   'booking_id': 1132038,
#   'action': 'dropoff',
#   'scheduled_time': 22527,
#   'node_id': 8},
#  {'run_id': 2,
#   'booking_id': 1129860,
#   'action': 'pickup',
#   'scheduled_time': 23658,
#   'node_id': 15},
#  {'run_id': 2,
#   'booking_id': 1129860,
#   'action': 'dropoff',
#   'scheduled_time': 24099,
#   'node_id': 16},
#  {'run_id': 2,
#   'booking_id': 1129898,
#   'action': 'pickup',
#   'scheduled_time': 27900,
#   'node_id': 43},
#  {'run_id': 2,
#   'booking_id': 1129836,
#   'action': 'pickup',
#   'scheduled_time': 28800,
#   'node_id': 51},
#  {'run_id': 2,
#   'booking_id': 1130494,
#   'action': 'pickup',
#   'scheduled_time': 29700,
#   'node_id': 65},
#  {'run_id': 2,
#   'booking_id': 1129898,
#   'action': 'dropoff',
#   'scheduled_time': 30784,
#   'node_id': 44},
#  {'run_id': 2,
#   'booking_id': 1129836,
#   'action': 'dropoff',
#   'scheduled_time': 31275,
#   'node_id': 52},
#  {'run_id': 2,
#   'booking_id': 1130494,
#   'action': 'dropoff',
#   'scheduled_time': 31807,
#   'node_id': 66},
#  {'run_id': 2,
#   'booking_id': 1130226,
#   'action': 'pickup',
#   'scheduled_time': 34200,
#   'node_id': 97},
#  {'run_id': 2,
#   'booking_id': 1130223,
#   'action': 'pickup',
#   'scheduled_time': 36000,
#   'node_id': 107},
#  {'run_id': 2,
#   'booking_id': 1130226,
#   'action': 'dropoff',
#   'scheduled_time': 36993,
#   'node_id': 98},
#  {'run_id': 2,
#   'booking_id': 1130223,
#   'action': 'dropoff',
#   'scheduled_time': 37694,
#   'node_id': 108},
#  {'run_id': 2,
#   'booking_id': 1128152,
#   'action': 'pickup',
#   'scheduled_time': 48600,
#   'node_id': 205},
#  {'run_id': 2,
#   'booking_id': 1132006,
#   'action': 'pickup',
#   'scheduled_time': 49050,
#   'node_id': 193},
#  {'run_id': 2,
#   'booking_id': 1132006,
#   'action': 'dropoff',
#   'scheduled_time': 49671,
#   'node_id': 194},
#  {'run_id': 2,
#   'booking_id': 1128152,
#   'action': 'dropoff',
#   'scheduled_time': 50733,
#   'node_id': 206},
#  {'run_id': 2,
#   'booking_id': 1129831,
#   'action': 'pickup',
#   'scheduled_time': 51505,
#   'node_id': 227},
#  {'run_id': 2,
#   'booking_id': 1129831,
#   'action': 'dropoff',
#   'scheduled_time': 52477,
#   'node_id': 228},
#  {'run_id': 3,
#   'booking_id': 1129894,
#   'action': 'pickup',
#   'scheduled_time': 19800,
#   'node_id': 3},
#  {'run_id': 3,
#   'booking_id': 1129894,
#   'action': 'dropoff',
#   'scheduled_time': 20825,
#   'node_id': 4},
#  {'run_id': 3,
#   'booking_id': 1129458,
#   'action': 'pickup',
#   'scheduled_time': 26100,
#   'node_id': 17},
#  {'run_id': 3,
#   'booking_id': 1129458,
#   'action': 'dropoff',
#   'scheduled_time': 27037,
#   'node_id': 18},
#  {'run_id': 3,
#   'booking_id': 1129588,
#   'action': 'pickup',
#   'scheduled_time': 27982,
#   'node_id': 45},
#  {'run_id': 3,
#   'booking_id': 1127790,
#   'action': 'pickup',
#   'scheduled_time': 28887,
#   'node_id': 47},
#  {'run_id': 3,
#   'booking_id': 1129588,
#   'action': 'dropoff',
#   'scheduled_time': 30012,
#   'node_id': 46},
#  {'run_id': 3,
#   'booking_id': 1127790,
#   'action': 'dropoff',
#   'scheduled_time': 30583,
#   'node_id': 48},
#  {'run_id': 3,
#   'booking_id': 1129838,
#   'action': 'pickup',
#   'scheduled_time': 35100,
#   'node_id': 103},
#  {'run_id': 3,
#   'booking_id': 1129838,
#   'action': 'dropoff',
#   'scheduled_time': 35712,
#   'node_id': 104},
#  {'run_id': 3,
#   'booking_id': 1130208,
#   'action': 'pickup',
#   'scheduled_time': 36483,
#   'node_id': 105},
#  {'run_id': 3,
#   'booking_id': 1130208,
#   'action': 'dropoff',
#   'scheduled_time': 38067,
#   'node_id': 106},
#  {'run_id': 3,
#   'booking_id': 1130209,
#   'action': 'pickup',
#   'scheduled_time': 43200,
#   'node_id': 159},
#  {'run_id': 3,
#   'booking_id': 1130209,
#   'action': 'dropoff',
#   'scheduled_time': 44872,
#   'node_id': 160},
#  {'run_id': 4,
#   'booking_id': 1129846,
#   'action': 'pickup',
#   'scheduled_time': 36000,
#   'node_id': 113},
#  {'run_id': 4,
#   'booking_id': 1129862,
#   'action': 'pickup',
#   'scheduled_time': 37200,
#   'node_id': 131},
#  {'run_id': 4,
#   'booking_id': 1129881,
#   'action': 'pickup',
#   'scheduled_time': 37951,
#   'node_id': 133},
#  {'run_id': 4,
#   'booking_id': 1129846,
#   'action': 'dropoff',
#   'scheduled_time': 38367,
#   'node_id': 114},
#  {'run_id': 4,
#   'booking_id': 1129862,
#   'action': 'dropoff',
#   'scheduled_time': 38667,
#   'node_id': 132},
#  {'run_id': 4,
#   'booking_id': 1129881,
#   'action': 'dropoff',
#   'scheduled_time': 38967,
#   'node_id': 134},
#  {'run_id': 4,
#   'booking_id': 1129872,
#   'action': 'pickup',
#   'scheduled_time': 41400,
#   'node_id': 145},
#  {'run_id': 4,
#   'booking_id': 1129913,
#   'action': 'pickup',
#   'scheduled_time': 41700,
#   'node_id': 147},
#  {'run_id': 4,
#   'booking_id': 1129872,
#   'action': 'dropoff',
#   'scheduled_time': 42230,
#   'node_id': 146},
#  {'run_id': 4,
#   'booking_id': 1129913,
#   'action': 'dropoff',
#   'scheduled_time': 42852,
#   'node_id': 148},
#  {'run_id': 4,
#   'booking_id': 1132318,
#   'action': 'pickup',
#   'scheduled_time': 46800,
#   'node_id': 185},
#  {'run_id': 4,
#   'booking_id': 1132318,
#   'action': 'dropoff',
#   'scheduled_time': 47243,
#   'node_id': 186},
#  {'run_id': 4,
#   'booking_id': 1129867,
#   'action': 'pickup',
#   'scheduled_time': 47855,
#   'node_id': 197},
#  {'run_id': 4,
#   'booking_id': 1132347,
#   'action': 'pickup',
#   'scheduled_time': 48242,
#   'node_id': 191},
#  {'run_id': 4,
#   'booking_id': 1132347,
#   'action': 'dropoff',
#   'scheduled_time': 49077,
#   'node_id': 192},
#  {'run_id': 4,
#   'booking_id': 1129867,
#   'action': 'dropoff',
#   'scheduled_time': 49765,
#   'node_id': 198},
#  {'run_id': 4,
#   'booking_id': 1129863,
#   'action': 'pickup',
#   'scheduled_time': 52560,
#   'node_id': 251},
#  {'run_id': 4,
#   'booking_id': 1129882,
#   'action': 'pickup',
#   'scheduled_time': 52860,
#   'node_id': 249},
#  {'run_id': 4,
#   'booking_id': 1129882,
#   'action': 'dropoff',
#   'scheduled_time': 53278,
#   'node_id': 250},
#  {'run_id': 4,
#   'booking_id': 1129863,
#   'action': 'dropoff',
#   'scheduled_time': 54028,
#   'node_id': 252},
#  {'run_id': 4,
#   'booking_id': 1133191,
#   'action': 'pickup',
#   'scheduled_time': 54705,
#   'node_id': 273},
#  {'run_id': 4,
#   'booking_id': 1133191,
#   'action': 'dropoff',
#   'scheduled_time': 55152,
#   'node_id': 274},
#  {'run_id': 5,
#   'booking_id': 1129920,
#   'action': 'pickup',
#   'scheduled_time': 26147,
#   'node_id': 19},
#  {'run_id': 5,
#   'booking_id': 1129920,
#   'action': 'dropoff',
#   'scheduled_time': 27316,
#   'node_id': 20},
#  {'run_id': 5,
#   'booking_id': 1129901,
#   'action': 'pickup',
#   'scheduled_time': 27920,
#   'node_id': 33},
#  {'run_id': 5,
#   'booking_id': 1129901,
#   'action': 'dropoff',
#   'scheduled_time': 28600,
#   'node_id': 34},
#  {'run_id': 5,
#   'booking_id': 1132300,
#   'action': 'pickup',
#   'scheduled_time': 29315,
#   'node_id': 59},
#  {'run_id': 5,
#   'booking_id': 1128560,
#   'action': 'pickup',
#   'scheduled_time': 30348,
#   'node_id': 69},
#  {'run_id': 5,
#   'booking_id': 1132300,
#   'action': 'dropoff',
#   'scheduled_time': 31195,
#   'node_id': 60},
#  {'run_id': 5,
#   'booking_id': 1128560,
#   'action': 'dropoff',
#   'scheduled_time': 32074,
#   'node_id': 70},
#  {'run_id': 5,
#   'booking_id': 1130177,
#   'action': 'pickup',
#   'scheduled_time': 33300,
#   'node_id': 91},
#  {'run_id': 5,
#   'booking_id': 1128144,
#   'action': 'pickup',
#   'scheduled_time': 35031,
#   'node_id': 95},
#  {'run_id': 5,
#   'booking_id': 1130177,
#   'action': 'dropoff',
#   'scheduled_time': 35862,
#   'node_id': 92},
#  {'run_id': 5,
#   'booking_id': 1130178,
#   'action': 'pickup',
#   'scheduled_time': 36162,
#   'node_id': 111},
#  {'run_id': 5,
#   'booking_id': 1128144,
#   'action': 'dropoff',
#   'scheduled_time': 37078,
#   'node_id': 96},
#  {'run_id': 5,
#   'booking_id': 1130178,
#   'action': 'dropoff',
#   'scheduled_time': 38158,
#   'node_id': 112},
#  {'run_id': 5,
#   'booking_id': 1132328,
#   'action': 'pickup',
#   'scheduled_time': 39600,
#   'node_id': 141},
#  {'run_id': 5,
#   'booking_id': 1132328,
#   'action': 'dropoff',
#   'scheduled_time': 40105,
#   'node_id': 142},
#  {'run_id': 5,
#   'booking_id': 1128717,
#   'action': 'pickup',
#   'scheduled_time': 45900,
#   'node_id': 175},
#  {'run_id': 5,
#   'booking_id': 1128717,
#   'action': 'dropoff',
#   'scheduled_time': 46574,
#   'node_id': 176},
#  {'run_id': 5,
#   'booking_id': 1129837,
#   'action': 'pickup',
#   'scheduled_time': 49500,
#   'node_id': 217},
#  {'run_id': 5,
#   'booking_id': 1130219,
#   'action': 'pickup',
#   'scheduled_time': 49971,
#   'node_id': 211},
#  {'run_id': 5,
#   'booking_id': 1130219,
#   'action': 'dropoff',
#   'scheduled_time': 51129,
#   'node_id': 212},
#  {'run_id': 5,
#   'booking_id': 1129837,
#   'action': 'dropoff',
#   'scheduled_time': 52036,
#   'node_id': 218},
#  {'run_id': 5,
#   'booking_id': 1129890,
#   'action': 'pickup',
#   'scheduled_time': 55800,
#   'node_id': 281},
#  {'run_id': 5,
#   'booking_id': 1129870,
#   'action': 'pickup',
#   'scheduled_time': 56100,
#   'node_id': 279},
#  {'run_id': 5,
#   'booking_id': 1129890,
#   'action': 'dropoff',
#   'scheduled_time': 57539,
#   'node_id': 282},
#  {'run_id': 5,
#   'booking_id': 1129870,
#   'action': 'dropoff',
#   'scheduled_time': 57956,
#   'node_id': 280},
#  {'run_id': 5,
#   'booking_id': 1129925,
#   'action': 'pickup',
#   'scheduled_time': 58750,
#   'node_id': 297},
#  {'run_id': 5,
#   'booking_id': 1129925,
#   'action': 'dropoff',
#   'scheduled_time': 59262,
#   'node_id': 298},
#  {'run_id': 6,
#   'booking_id': 1129851,
#   'action': 'pickup',
#   'scheduled_time': 27000,
#   'node_id': 27},
#  {'run_id': 6,
#   'booking_id': 1129858,
#   'action': 'pickup',
#   'scheduled_time': 27686,
#   'node_id': 35},
#  {'run_id': 6,
#   'booking_id': 1129856,
#   'action': 'pickup',
#   'scheduled_time': 28136,
#   'node_id': 29},
#  {'run_id': 6,
#   'booking_id': 1129851,
#   'action': 'dropoff',
#   'scheduled_time': 28941,
#   'node_id': 28},
#  {'run_id': 6,
#   'booking_id': 1129856,
#   'action': 'dropoff',
#   'scheduled_time': 29528,
#   'node_id': 30},
#  {'run_id': 6,
#   'booking_id': 1129858,
#   'action': 'dropoff',
#   'scheduled_time': 30254,
#   'node_id': 36},
#  {'run_id': 6,
#   'booking_id': 1132335,
#   'action': 'pickup',
#   'scheduled_time': 33300,
#   'node_id': 83},
#  {'run_id': 6,
#   'booking_id': 1129841,
#   'action': 'pickup',
#   'scheduled_time': 34083,
#   'node_id': 89},
#  {'run_id': 6,
#   'booking_id': 1132335,
#   'action': 'dropoff',
#   'scheduled_time': 34834,
#   'node_id': 84},
#  {'run_id': 6,
#   'booking_id': 1129841,
#   'action': 'dropoff',
#   'scheduled_time': 35744,
#   'node_id': 90},
#  {'run_id': 6,
#   'booking_id': 1130203,
#   'action': 'pickup',
#   'scheduled_time': 36533,
#   'node_id': 109},
#  {'run_id': 6,
#   'booking_id': 1129849,
#   'action': 'pickup',
#   'scheduled_time': 37254,
#   'node_id': 123},
#  {'run_id': 6,
#   'booking_id': 1129849,
#   'action': 'dropoff',
#   'scheduled_time': 37897,
#   'node_id': 124},
#  {'run_id': 6,
#   'booking_id': 1130203,
#   'action': 'dropoff',
#   'scheduled_time': 38477,
#   'node_id': 110},
#  {'run_id': 6,
#   'booking_id': 1130247,
#   'action': 'pickup',
#   'scheduled_time': 40500,
#   'node_id': 143},
#  {'run_id': 6,
#   'booking_id': 1130227,
#   'action': 'pickup',
#   'scheduled_time': 41400,
#   'node_id': 149},
#  {'run_id': 6,
#   'booking_id': 1130247,
#   'action': 'dropoff',
#   'scheduled_time': 42027,
#   'node_id': 144},
#  {'run_id': 6,
#   'booking_id': 1130227,
#   'action': 'dropoff',
#   'scheduled_time': 43069,
#   'node_id': 150},
#  {'run_id': 6,
#   'booking_id': 1130220,
#   'action': 'pickup',
#   'scheduled_time': 43792,
#   'node_id': 161},
#  {'run_id': 6,
#   'booking_id': 1130205,
#   'action': 'pickup',
#   'scheduled_time': 45000,
#   'node_id': 167},
#  {'run_id': 6,
#   'booking_id': 1130220,
#   'action': 'dropoff',
#   'scheduled_time': 45738,
#   'node_id': 162},
#  {'run_id': 6,
#   'booking_id': 1130205,
#   'action': 'dropoff',
#   'scheduled_time': 46233,
#   'node_id': 168},
#  {'run_id': 6,
#   'booking_id': 1130206,
#   'action': 'pickup',
#   'scheduled_time': 46533,
#   'node_id': 179},
#  {'run_id': 6,
#   'booking_id': 1130206,
#   'action': 'dropoff',
#   'scheduled_time': 47208,
#   'node_id': 180},
#  {'run_id': 6,
#   'booking_id': 1129603,
#   'action': 'pickup',
#   'scheduled_time': 49500,
#   'node_id': 219},
#  {'run_id': 6,
#   'booking_id': 1129857,
#   'action': 'pickup',
#   'scheduled_time': 49800,
#   'node_id': 213},
#  {'run_id': 6,
#   'booking_id': 1129857,
#   'action': 'dropoff',
#   'scheduled_time': 50670,
#   'node_id': 214},
#  {'run_id': 6,
#   'booking_id': 1129603,
#   'action': 'dropoff',
#   'scheduled_time': 51239,
#   'node_id': 220},
#  {'run_id': 6,
#   'booking_id': 1130207,
#   'action': 'pickup',
#   'scheduled_time': 53100,
#   'node_id': 253},
#  {'run_id': 6,
#   'booking_id': 1129832,
#   'action': 'pickup',
#   'scheduled_time': 53590,
#   'node_id': 247},
#  {'run_id': 6,
#   'booking_id': 1129832,
#   'action': 'dropoff',
#   'scheduled_time': 54312,
#   'node_id': 248},
#  {'run_id': 6,
#   'booking_id': 1130207,
#   'action': 'dropoff',
#   'scheduled_time': 54887,
#   'node_id': 254},
#  {'run_id': 6,
#   'booking_id': 1130017,
#   'action': 'pickup',
#   'scheduled_time': 55439,
#   'node_id': 263},
#  {'run_id': 6,
#   'booking_id': 1130017,
#   'action': 'dropoff',
#   'scheduled_time': 56262,
#   'node_id': 264},
#  {'run_id': 6,
#   'booking_id': 1129885,
#   'action': 'pickup',
#   'scheduled_time': 57600,
#   'node_id': 291},
#  {'run_id': 6,
#   'booking_id': 1132042,
#   'action': 'pickup',
#   'scheduled_time': 58500,
#   'node_id': 299},
#  {'run_id': 6,
#   'booking_id': 1129885,
#   'action': 'dropoff',
#   'scheduled_time': 59412,
#   'node_id': 292},
#  {'run_id': 6,
#   'booking_id': 1132042,
#   'action': 'dropoff',
#   'scheduled_time': 59873,
#   'node_id': 300},
#  {'run_id': 6,
#   'booking_id': 1129902,
#   'action': 'pickup',
#   'scheduled_time': 60849,
#   'node_id': 313},
#  {'run_id': 6,
#   'booking_id': 1129903,
#   'action': 'pickup',
#   'scheduled_time': 61149,
#   'node_id': 315},
#  {'run_id': 6,
#   'booking_id': 1129902,
#   'action': 'dropoff',
#   'scheduled_time': 61864,
#   'node_id': 314},
#  {'run_id': 6,
#   'booking_id': 1129903,
#   'action': 'dropoff',
#   'scheduled_time': 62718,
#   'node_id': 316},
#  {'run_id': 7,
#   'booking_id': 1129908,
#   'action': 'pickup',
#   'scheduled_time': 28800,
#   'node_id': 55},
#  {'run_id': 7,
#   'booking_id': 1127353,
#   'action': 'pickup',
#   'scheduled_time': 30550,
#   'node_id': 67},
#  {'run_id': 7,
#   'booking_id': 1129908,
#   'action': 'dropoff',
#   'scheduled_time': 31522,
#   'node_id': 56},
#  {'run_id': 7,
#   'booking_id': 1127353,
#   'action': 'dropoff',
#   'scheduled_time': 32052,
#   'node_id': 68},
#  {'run_id': 7,
#   'booking_id': 1129879,
#   'action': 'pickup',
#   'scheduled_time': 36000,
#   'node_id': 115},
#  {'run_id': 7,
#   'booking_id': 1129879,
#   'action': 'dropoff',
#   'scheduled_time': 36780,
#   'node_id': 116},
#  {'run_id': 7,
#   'booking_id': 1130199,
#   'action': 'pickup',
#   'scheduled_time': 42300,
#   'node_id': 153},
#  {'run_id': 7,
#   'booking_id': 1130199,
#   'action': 'dropoff',
#   'scheduled_time': 42897,
#   'node_id': 154},
#  {'run_id': 7,
#   'booking_id': 1130200,
#   'action': 'pickup',
#   'scheduled_time': 50400,
#   'node_id': 233},
#  {'run_id': 7,
#   'booking_id': 1123500,
#   'action': 'pickup',
#   'scheduled_time': 51300,
#   'node_id': 243},
#  {'run_id': 7,
#   'booking_id': 1130200,
#   'action': 'dropoff',
#   'scheduled_time': 51757,
#   'node_id': 234},
#  {'run_id': 7,
#   'booking_id': 1123500,
#   'action': 'dropoff',
#   'scheduled_time': 53112,
#   'node_id': 244},
#  {'run_id': 7,
#   'booking_id': 1129842,
#   'action': 'pickup',
#   'scheduled_time': 54013,
#   'node_id': 265},
#  {'run_id': 7,
#   'booking_id': 1130239,
#   'action': 'pickup',
#   'scheduled_time': 54784,
#   'node_id': 257},
#  {'run_id': 7,
#   'booking_id': 1130239,
#   'action': 'dropoff',
#   'scheduled_time': 55822,
#   'node_id': 258},
#  {'run_id': 7,
#   'booking_id': 1129842,
#   'action': 'dropoff',
#   'scheduled_time': 56782,
#   'node_id': 266},
#  {'run_id': 7,
#   'booking_id': 1129906,
#   'action': 'pickup',
#   'scheduled_time': 58500,
#   'node_id': 295},
#  {'run_id': 7,
#   'booking_id': 1129834,
#   'action': 'pickup',
#   'scheduled_time': 59498,
#   'node_id': 311},
#  {'run_id': 7,
#   'booking_id': 1129834,
#   'action': 'dropoff',
#   'scheduled_time': 60113,
#   'node_id': 312},
#  {'run_id': 7,
#   'booking_id': 1129906,
#   'action': 'dropoff',
#   'scheduled_time': 60829,
#   'node_id': 296},
#  {'run_id': 7,
#   'booking_id': 1129907,
#   'action': 'pickup',
#   'scheduled_time': 61448,
#   'node_id': 317},
#  {'run_id': 7,
#   'booking_id': 1129907,
#   'action': 'dropoff',
#   'scheduled_time': 62225,
#   'node_id': 318},
#  {'run_id': 8,
#   'booking_id': 1129916,
#   'action': 'pickup',
#   'scheduled_time': 28800,
#   'node_id': 57},
#  {'run_id': 8,
#   'booking_id': 1128432,
#   'action': 'pickup',
#   'scheduled_time': 29359,
#   'node_id': 41},
#  {'run_id': 8,
#   'booking_id': 1128432,
#   'action': 'dropoff',
#   'scheduled_time': 29827,
#   'node_id': 42},
#  {'run_id': 8,
#   'booking_id': 1129916,
#   'action': 'dropoff',
#   'scheduled_time': 30797,
#   'node_id': 58},
#  {'run_id': 8,
#   'booking_id': 1130173,
#   'action': 'pickup',
#   'scheduled_time': 31638,
#   'node_id': 73},
#  {'run_id': 8,
#   'booking_id': 1130173,
#   'action': 'dropoff',
#   'scheduled_time': 32382,
#   'node_id': 74},
#  {'run_id': 8,
#   'booking_id': 1132351,
#   'action': 'pickup',
#   'scheduled_time': 33358,
#   'node_id': 85},
#  {'run_id': 8,
#   'booking_id': 1132351,
#   'action': 'dropoff',
#   'scheduled_time': 34099,
#   'node_id': 86},
#  {'run_id': 8,
#   'booking_id': 1130174,
#   'action': 'pickup',
#   'scheduled_time': 36000,
#   'node_id': 119},
#  {'run_id': 8,
#   'booking_id': 1130174,
#   'action': 'dropoff',
#   'scheduled_time': 36744,
#   'node_id': 120},
#  {'run_id': 8,
#   'booking_id': 1129883,
#   'action': 'pickup',
#   'scheduled_time': 37800,
#   'node_id': 135},
#  {'run_id': 8,
#   'booking_id': 1129883,
#   'action': 'dropoff',
#   'scheduled_time': 38229,
#   'node_id': 136},
#  {'run_id': 8,
#   'booking_id': 1130689,
#   'action': 'pickup',
#   'scheduled_time': 43200,
#   'node_id': 163},
#  {'run_id': 8,
#   'booking_id': 1129910,
#   'action': 'pickup',
#   'scheduled_time': 44129,
#   'node_id': 157},
#  {'run_id': 8,
#   'booking_id': 1130689,
#   'action': 'dropoff',
#   'scheduled_time': 45021,
#   'node_id': 164},
#  {'run_id': 8,
#   'booking_id': 1129910,
#   'action': 'dropoff',
#   'scheduled_time': 45982,
#   'node_id': 158},
#  {'run_id': 8,
#   'booking_id': 1130191,
#   'action': 'pickup',
#   'scheduled_time': 46632,
#   'node_id': 173},
#  {'run_id': 8,
#   'booking_id': 1130191,
#   'action': 'dropoff',
#   'scheduled_time': 47495,
#   'node_id': 174},
#  {'run_id': 8,
#   'booking_id': 1129884,
#   'action': 'pickup',
#   'scheduled_time': 48152,
#   'node_id': 189},
#  {'run_id': 8,
#   'booking_id': 1129884,
#   'action': 'dropoff',
#   'scheduled_time': 49156,
#   'node_id': 190},
#  {'run_id': 8,
#   'booking_id': 1132337,
#   'action': 'pickup',
#   'scheduled_time': 50400,
#   'node_id': 237},
#  {'run_id': 8,
#   'booking_id': 1130670,
#   'action': 'pickup',
#   'scheduled_time': 51300,
#   'node_id': 241},
#  {'run_id': 8,
#   'booking_id': 1128718,
#   'action': 'pickup',
#   'scheduled_time': 51671,
#   'node_id': 225},
#  {'run_id': 8,
#   'booking_id': 1130670,
#   'action': 'dropoff',
#   'scheduled_time': 52049,
#   'node_id': 242},
#  {'run_id': 8,
#   'booking_id': 1128718,
#   'action': 'dropoff',
#   'scheduled_time': 52647,
#   'node_id': 226},
#  {'run_id': 8,
#   'booking_id': 1132337,
#   'action': 'dropoff',
#   'scheduled_time': 53591,
#   'node_id': 238},
#  {'run_id': 8,
#   'booking_id': 1129829,
#   'action': 'pickup',
#   'scheduled_time': 54309,
#   'node_id': 267},
#  {'run_id': 8,
#   'booking_id': 1129829,
#   'action': 'dropoff',
#   'scheduled_time': 55589,
#   'node_id': 268},
#  {'run_id': 8,
#   'booking_id': 1129880,
#   'action': 'pickup',
#   'scheduled_time': 57600,
#   'node_id': 289},
#  {'run_id': 8,
#   'booking_id': 1129880,
#   'action': 'dropoff',
#   'scheduled_time': 58355,
#   'node_id': 290},
#  {'run_id': 8,
#   'booking_id': 1129911,
#   'action': 'pickup',
#   'scheduled_time': 59400,
#   'node_id': 303},
#  {'run_id': 8,
#   'booking_id': 1129859,
#   'action': 'pickup',
#   'scheduled_time': 60068,
#   'node_id': 309},
#  {'run_id': 8,
#   'booking_id': 1129859,
#   'action': 'dropoff',
#   'scheduled_time': 61109,
#   'node_id': 310},
#  {'run_id': 8,
#   'booking_id': 1132636,
#   'action': 'pickup',
#   'scheduled_time': 61812,
#   'node_id': 319},
#  {'run_id': 8,
#   'booking_id': 1129911,
#   'action': 'dropoff',
#   'scheduled_time': 62699,
#   'node_id': 304},
#  {'run_id': 8,
#   'booking_id': 1132636,
#   'action': 'dropoff',
#   'scheduled_time': 63627,
#   'node_id': 320},
#  {'run_id': 9,
#   'booking_id': 1129866,
#   'action': 'pickup',
#   'scheduled_time': 27000,
#   'node_id': 31},
#  {'run_id': 9,
#   'booking_id': 1129929,
#   'action': 'pickup',
#   'scheduled_time': 27557,
#   'node_id': 21},
#  {'run_id': 9,
#   'booking_id': 1129866,
#   'action': 'dropoff',
#   'scheduled_time': 28376,
#   'node_id': 32},
#  {'run_id': 9,
#   'booking_id': 1129929,
#   'action': 'dropoff',
#   'scheduled_time': 28689,
#   'node_id': 22},
#  {'run_id': 9,
#   'booking_id': 1130218,
#   'action': 'pickup',
#   'scheduled_time': 30600,
#   'node_id': 75},
#  {'run_id': 9,
#   'booking_id': 1129869,
#   'action': 'pickup',
#   'scheduled_time': 31413,
#   'node_id': 61},
#  {'run_id': 9,
#   'booking_id': 1130218,
#   'action': 'dropoff',
#   'scheduled_time': 32283,
#   'node_id': 76},
#  {'run_id': 9,
#   'booking_id': 1129869,
#   'action': 'dropoff',
#   'scheduled_time': 33189,
#   'node_id': 62},
#  {'run_id': 9,
#   'booking_id': 1132327,
#   'action': 'pickup',
#   'scheduled_time': 34800,
#   'node_id': 101},
#  {'run_id': 9,
#   'booking_id': 1132327,
#   'action': 'dropoff',
#   'scheduled_time': 35327,
#   'node_id': 102},
#  {'run_id': 9,
#   'booking_id': 1123476,
#   'action': 'pickup',
#   'scheduled_time': 36236,
#   'node_id': 117},
#  {'run_id': 9,
#   'booking_id': 1129899,
#   'action': 'pickup',
#   'scheduled_time': 37872,
#   'node_id': 125},
#  {'run_id': 9,
#   'booking_id': 1123476,
#   'action': 'dropoff',
#   'scheduled_time': 39016,
#   'node_id': 118},
#  {'run_id': 9,
#   'booking_id': 1129899,
#   'action': 'dropoff',
#   'scheduled_time': 39518,
#   'node_id': 126},
#  {'run_id': 9,
#   'booking_id': 1129861,
#   'action': 'pickup',
#   'scheduled_time': 46800,
#   'node_id': 181},
#  {'run_id': 9,
#   'booking_id': 1129886,
#   'action': 'pickup',
#   'scheduled_time': 47700,
#   'node_id': 195},
#  {'run_id': 9,
#   'booking_id': 1129861,
#   'action': 'dropoff',
#   'scheduled_time': 48074,
#   'node_id': 182},
#  {'run_id': 9,
#   'booking_id': 1132334,
#   'action': 'pickup',
#   'scheduled_time': 48600,
#   'node_id': 209},
#  {'run_id': 9,
#   'booking_id': 1129886,
#   'action': 'dropoff',
#   'scheduled_time': 49075,
#   'node_id': 196},
#  {'run_id': 9,
#   'booking_id': 1132334,
#   'action': 'dropoff',
#   'scheduled_time': 49738,
#   'node_id': 210},
#  {'run_id': 9,
#   'booking_id': 1127802,
#   'action': 'pickup',
#   'scheduled_time': 50466,
#   'node_id': 223},
#  {'run_id': 9,
#   'booking_id': 1129848,
#   'action': 'pickup',
#   'scheduled_time': 51040,
#   'node_id': 221},
#  {'run_id': 9,
#   'booking_id': 1129848,
#   'action': 'dropoff',
#   'scheduled_time': 51738,
#   'node_id': 222},
#  {'run_id': 9,
#   'booking_id': 1127802,
#   'action': 'dropoff',
#   'scheduled_time': 52824,
#   'node_id': 224},
#  {'run_id': 9,
#   'booking_id': 1130221,
#   'action': 'pickup',
#   'scheduled_time': 53731,
#   'node_id': 255},
#  {'run_id': 9,
#   'booking_id': 1129873,
#   'action': 'pickup',
#   'scheduled_time': 54851,
#   'node_id': 271},
#  {'run_id': 9,
#   'booking_id': 1130221,
#   'action': 'dropoff',
#   'scheduled_time': 55569,
#   'node_id': 256},
#  {'run_id': 9,
#   'booking_id': 1129873,
#   'action': 'dropoff',
#   'scheduled_time': 56154,
#   'node_id': 272},
#  {'run_id': 9,
#   'booking_id': 1130259,
#   'action': 'pickup',
#   'scheduled_time': 56700,
#   'node_id': 287},
#  {'run_id': 9,
#   'booking_id': 1130259,
#   'action': 'dropoff',
#   'scheduled_time': 57273,
#   'node_id': 288},
#  {'run_id': 9,
#   'booking_id': 1132354,
#   'action': 'pickup',
#   'scheduled_time': 58277,
#   'node_id': 293},
#  {'run_id': 9,
#   'booking_id': 1132354,
#   'action': 'dropoff',
#   'scheduled_time': 59021,
#   'node_id': 294},
#  {'run_id': 9,
#   'booking_id': 1130403,
#   'action': 'pickup',
#   'scheduled_time': 59623,
#   'node_id': 305},
#  {'run_id': 9,
#   'booking_id': 1129843,
#   'action': 'pickup',
#   'scheduled_time': 60631,
#   'node_id': 307},
#  {'run_id': 9,
#   'booking_id': 1129843,
#   'action': 'dropoff',
#   'scheduled_time': 61975,
#   'node_id': 308},
#  {'run_id': 9,
#   'booking_id': 1130403,
#   'action': 'dropoff',
#   'scheduled_time': 62834,
#   'node_id': 306},
#  {'run_id': 10,
#   'booking_id': 1130500,
#   'action': 'pickup',
#   'scheduled_time': 55800,
#   'node_id': 283},
#  {'run_id': 10,
#   'booking_id': 1129839,
#   'action': 'pickup',
#   'scheduled_time': 56486,
#   'node_id': 285},
#  {'run_id': 10,
#   'booking_id': 1129839,
#   'action': 'dropoff',
#   'scheduled_time': 57095,
#   'node_id': 286},
#  {'run_id': 10,
#   'booking_id': 1130500,
#   'action': 'dropoff',
#   'scheduled_time': 58070,
#   'node_id': 284},
#  {'run_id': 10,
#   'booking_id': 1129927,
#   'action': 'pickup',
#   'scheduled_time': 63900,
#   'node_id': 321},
#  {'run_id': 10,
#   'booking_id': 1129927,
#   'action': 'dropoff',
#   'scheduled_time': 64934,
#   'node_id': 322},
#  {'run_id': 10,
#   'booking_id': 1129905,
#   'action': 'pickup',
#   'scheduled_time': 66000,
#   'node_id': 325},
#  {'run_id': 10,
#   'booking_id': 1129917,
#   'action': 'pickup',
#   'scheduled_time': 66300,
#   'node_id': 323},
#  {'run_id': 10,
#   'booking_id': 1129917,
#   'action': 'dropoff',
#   'scheduled_time': 67510,
#   'node_id': 324},
#  {'run_id': 10,
#   'booking_id': 1129905,
#   'action': 'dropoff',
#   'scheduled_time': 68710,
#   'node_id': 326},
#  {'run_id': 10,
#   'booking_id': 1129897,
#   'action': 'pickup',
#   'scheduled_time': 72000,
#   'node_id': 327},
#  {'run_id': 10,
#   'booking_id': 1130027,
#   'action': 'pickup',
#   'scheduled_time': 72900,
#   'node_id': 329},
#  {'run_id': 10,
#   'booking_id': 1130027,
#   'action': 'dropoff',
#   'scheduled_time': 73722,
#   'node_id': 330},
#  {'run_id': 10,
#   'booking_id': 1129897,
#   'action': 'dropoff',
#   'scheduled_time': 74921,
#   'node_id': 328},
#  {'run_id': 10,
#   'booking_id': 1132374,
#   'action': 'pickup',
#   'scheduled_time': 76500,
#   'node_id': 335},
#  {'run_id': 10,
#   'booking_id': 1132374,
#   'action': 'dropoff',
#   'scheduled_time': 77498,
#   'node_id': 336},
#  {'run_id': 11,
#   'booking_id': 1132369,
#   'action': 'pickup',
#   'scheduled_time': 46800,
#   'node_id': 187},
#  {'run_id': 11,
#   'booking_id': 1132369,
#   'action': 'dropoff',
#   'scheduled_time': 47784,
#   'node_id': 188},
#  {'run_id': 11,
#   'booking_id': 1127376,
#   'action': 'pickup',
#   'scheduled_time': 48600,
#   'node_id': 203},
#  {'run_id': 11,
#   'booking_id': 1127376,
#   'action': 'dropoff',
#   'scheduled_time': 49548,
#   'node_id': 204},
#  {'run_id': 11,
#   'booking_id': 1129909,
#   'action': 'pickup',
#   'scheduled_time': 51300,
#   'node_id': 239},
#  {'run_id': 11,
#   'booking_id': 1129909,
#   'action': 'dropoff',
#   'scheduled_time': 52641,
#   'node_id': 240},
#  {'run_id': 11,
#   'booking_id': 1129887,
#   'action': 'pickup',
#   'scheduled_time': 54000,
#   'node_id': 261},
#  {'run_id': 11,
#   'booking_id': 1129371,
#   'action': 'pickup',
#   'scheduled_time': 54640,
#   'node_id': 269},
#  {'run_id': 11,
#   'booking_id': 1129371,
#   'action': 'dropoff',
#   'scheduled_time': 54979,
#   'node_id': 270},
#  {'run_id': 11,
#   'booking_id': 1129887,
#   'action': 'dropoff',
#   'scheduled_time': 55455,
#   'node_id': 262},
#  {'run_id': 11,
#   'booking_id': 1132314,
#   'action': 'pickup',
#   'scheduled_time': 59400,
#   'node_id': 301},
#  {'run_id': 11,
#   'booking_id': 1132314,
#   'action': 'dropoff',
#   'scheduled_time': 59839,
#   'node_id': 302},
#  {'run_id': 11,
#   'booking_id': 1132011,
#   'action': 'pickup',
#   'scheduled_time': 72900,
#   'node_id': 331},
#  {'run_id': 11,
#   'booking_id': 1132011,
#   'action': 'dropoff',
#   'scheduled_time': 73525,
#   'node_id': 332},
#  {'run_id': 11,
#   'booking_id': 1132363,
#   'action': 'pickup',
#   'scheduled_time': 76500,
#   'node_id': 333},
#  {'run_id': 11,
#   'booking_id': 1132363,
#   'action': 'dropoff',
#   'scheduled_time': 77110,
#   'node_id': 334},
#  {'run_id': 11,
#   'booking_id': 1129888,
#   'action': 'pickup',
#   'scheduled_time': 77410,
#   'node_id': 337},
#  {'run_id': 11,
#   'booking_id': 1129888,
#   'action': 'dropoff',
#   'scheduled_time': 77965,
#   'node_id': 338},
#  {'run_id': 12,
#   'booking_id': 1131490,
#   'action': 'pickup',
#   'scheduled_time': 29700,
#   'node_id': 63},
#  {'run_id': 12,
#   'booking_id': 1129840,
#   'action': 'pickup',
#   'scheduled_time': 30143,
#   'node_id': 53},
#  {'run_id': 12,
#   'booking_id': 1129840,
#   'action': 'dropoff',
#   'scheduled_time': 30841,
#   'node_id': 54},
#  {'run_id': 12,
#   'booking_id': 1131490,
#   'action': 'dropoff',
#   'scheduled_time': 31536,
#   'node_id': 64},
#  {'run_id': 12,
#   'booking_id': 1129889,
#   'action': 'pickup',
#   'scheduled_time': 33300,
#   'node_id': 93},
#  {'run_id': 12,
#   'booking_id': 1132333,
#   'action': 'pickup',
#   'scheduled_time': 34253,
#   'node_id': 87},
#  {'run_id': 12,
#   'booking_id': 1132333,
#   'action': 'dropoff',
#   'scheduled_time': 35058,
#   'node_id': 88},
#  {'run_id': 12,
#   'booking_id': 1129889,
#   'action': 'dropoff',
#   'scheduled_time': 35767,
#   'node_id': 94},
#  {'run_id': 12,
#   'booking_id': 1130236,
#   'action': 'pickup',
#   'scheduled_time': 37800,
#   'node_id': 137},
#  {'run_id': 12,
#   'booking_id': 1132329,
#   'action': 'pickup',
#   'scheduled_time': 38532,
#   'node_id': 129},
#  {'run_id': 12,
#   'booking_id': 1132329,
#   'action': 'dropoff',
#   'scheduled_time': 39747,
#   'node_id': 130},
#  {'run_id': 12,
#   'booking_id': 1130236,
#   'action': 'dropoff',
#   'scheduled_time': 40047,
#   'node_id': 138},
#  {'run_id': 12,
#   'booking_id': 1130237,
#   'action': 'pickup',
#   'scheduled_time': 45000,
#   'node_id': 169},
#  {'run_id': 12,
#   'booking_id': 1130237,
#   'action': 'dropoff',
#   'scheduled_time': 46218,
#   'node_id': 170},
#  {'run_id': 12,
#   'booking_id': 1129878,
#   'action': 'pickup',
#   'scheduled_time': 46946,
#   'node_id': 183},
#  {'run_id': 12,
#   'booking_id': 1128459,
#   'action': 'pickup',
#   'scheduled_time': 47753,
#   'node_id': 199},
#  {'run_id': 12,
#   'booking_id': 1128459,
#   'action': 'dropoff',
#   'scheduled_time': 48221,
#   'node_id': 200},
#  {'run_id': 12,
#   'booking_id': 1129878,
#   'action': 'dropoff',
#   'scheduled_time': 49254,
#   'node_id': 184},
#  {'run_id': 12,
#   'booking_id': 1129896,
#   'action': 'pickup',
#   'scheduled_time': 50400,
#   'node_id': 229},
#  {'run_id': 12,
#   'booking_id': 1130258,
#   'action': 'pickup',
#   'scheduled_time': 51437,
#   'node_id': 235},
#  {'run_id': 12,
#   'booking_id': 1130258,
#   'action': 'dropoff',
#   'scheduled_time': 52002,
#   'node_id': 236},
#  {'run_id': 12,
#   'booking_id': 1126950,
#   'action': 'pickup',
#   'scheduled_time': 52630,
#   'node_id': 245},
#  {'run_id': 12,
#   'booking_id': 1126950,
#   'action': 'dropoff',
#   'scheduled_time': 53272,
#   'node_id': 246},
#  {'run_id': 12,
#   'booking_id': 1129896,
#   'action': 'dropoff',
#   'scheduled_time': 54046,
#   'node_id': 230},
#  {'run_id': 12,
#   'booking_id': 1132348,
#   'action': 'pickup',
#   'scheduled_time': 54346,
#   'node_id': 259},
#  {'run_id': 12,
#   'booking_id': 1132348,
#   'action': 'dropoff',
#   'scheduled_time': 55184,
#   'node_id': 260},
#  {'run_id': 12,
#   'booking_id': 1129855,
#   'action': 'pickup',
#   'scheduled_time': 55800,
#   'node_id': 277},
#  {'run_id': 12,
#   'booking_id': 1129847,
#   'action': 'pickup',
#   'scheduled_time': 56262,
#   'node_id': 275},
#  {'run_id': 12,
#   'booking_id': 1129855,
#   'action': 'dropoff',
#   'scheduled_time': 56816,
#   'node_id': 278},
#  {'run_id': 12,
#   'booking_id': 1129847,
#   'action': 'dropoff',
#   'scheduled_time': 57541,
#   'node_id': 276}]

# %%
with open('./data/offline_manifests.pkl', 'wb') as f:
    pickle.dump(manifests,f)

# %% [markdown]
# ## Metric Functions

# %%
def get_pt(pickup_lat, pickup_lon, dropoff_lat, dropoff_lon, action): 
    if action == 'pickup':
        r = {'lat': pickup_lat, 'lon': pickup_lon}
    elif action == 'dropoff':
        r = {'lat': dropoff_lat, 'lon': dropoff_lon}
    else:
        r = {'lat': config.DEPOT_LAT, 'lon': config.DEPOT_LON}
    return r
def manifest_report(df, payload):
    # df must have columns 'booking_id', 'scheduled_arrival_dt', 'action'
    
    # first sort by 'scheduled_time' so we don't have to assume df is in the correct order initially
    df = df.sort_values(by='scheduled_time')
    df['node_id'] = list(range(len(df)))
    
    # calculate 'occupancy' for manifest
    occupancy = [0]
    for i in range(1, len(df)):
        if df.iloc[i]['action'] == 'pickup':
            temp = occupancy[-1] + 1
        elif df.iloc[i]['action'] == 'dropoff':
            temp = occupancy[-1] - 1
        else:
            temp = 0
        occupancy.append(temp)
    df['occupancy'] = occupancy
    
    # need to get geolocation of each point so we can calculate distances, this requires merging with requests
    df_requests = pd.DataFrame(payload['requests'])
    df = pd.merge(df, df_requests, on='booking_id', how='left')
    df['pt'] = df.apply(lambda row: get_pt(row['pickup_pt']['lat'], row['pickup_pt']['lon'], row['dropoff_pt']['lat'], row['dropoff_pt']['lon'], row['action']), axis=1)
    df = df[['booking_id', 'scheduled_time', 'action', 'occupancy', 'node_id', 'pt']]
    
    # get travel_time_matrix and distance_matrix    
    distance_matrix = osrm.request_distance_matrix(df['pt'].tolist())

    # calculate number_of_passengers_served
    number_of_passengers_served = len(df[df['action']=='dropoff'])    
    total_distance, total_distance_without_passengers = 0, 0
    for i in range(len(df)-1):
        total_distance += distance_matrix[i][i+1]
        if df.iloc[i]['occupancy'] == 0:
            total_distance_without_passengers += distance_matrix[i][i+1]
    # Need to set up functions once osrm server is set up         
    from_depot = osrm.request_travel_distance({'lat': config.DEPOT_LAT, 'lon': config.DEPOT_LON}, df.iloc[0]['pt'])
    to_depot = osrm.request_travel_distance(df.iloc[-1]['pt'], {'lat': config.DEPOT_LAT, 'lon': config.DEPOT_LON})

    total_distance = total_distance + from_depot + to_depot
    total_distance_without_passengers = total_distance_without_passengers + from_depot + to_depot
    
    vehicle_miles_travelled = total_distance / 1609 # convert meters to miles
    vehicle_deadhead_miles = total_distance_without_passengers / 1609
    
    number_of_shared_rides = 0
    passenger_meters_travelled = 0
    for booking_id in df['booking_id'].unique():
        if booking_id != -1:
            pickup = df[(df['booking_id']==booking_id) & (df['action']=='pickup')].iloc[0]
            dropoff = df[(df['booking_id']==booking_id) & (df['action']=='dropoff')].iloc[0]
            dfrn = pd.DataFrame(payload['requests'])
            rn = dfrn[(dfrn['booking_id']==booking_id)].iloc[0]
            num_passengers = rn['am'] + rn['wc']
            passenger_meters_travelled += (distance_matrix[pickup['node_id']][dropoff['node_id']]) * num_passengers
            if (pickup['occupancy'] > 1) or (dropoff['occupancy'] > 0) or (dropoff['node_id'] - pickup['node_id'] != 1):
                number_of_shared_rides += 1
    
    passenger_miles_travelled = passenger_meters_travelled / 1609
    return {
        'VMT': vehicle_miles_travelled,
        'PMT': passenger_miles_travelled,
        'VMT_PMT_Ratio': vehicle_miles_travelled / passenger_miles_travelled,
        'VDM': vehicle_deadhead_miles,
        'number_of_passengers_served': number_of_passengers_served,
        'number_of_shared_rides': number_of_shared_rides,
        'Shared_Rate': int((number_of_shared_rides / number_of_passengers_served) * 100)
    }
    
def timetable_report(df, payload):
    # df must have columns 'booking_id', 'scheduled_arrival_dt', 'action', 'run_id'
    driver_runs_available = list({d['run_id'] for d in payload['driver_runs']})
    dfr = pd.DataFrame(payload['requests'])
    # dfr = dfr[dfr['leave_open']==False]
    vehicle_reports = []
    for run_id in driver_runs_available:
        df_run = df[df['run_id']==run_id]
        if len(df_run[df_run['action'].isin(['pickup', 'dropoff'])]) > 0:
            vehicle_report = manifest_report(
                df_run,
                payload,
            )
            vehicle_report['run_id'] = run_id
        else:
            vehicle_report = {
                'VMT': 0,
                'PMT': 0,
                'VMT_PMT_Ratio': 0,
                'VDM': 0,
                'number_of_passengers_served': 0,
                'number_of_shared_rides': 0,
                'Shared_Rate': 0,
                'run_id': run_id
            }
        vehicle_reports.append(vehicle_report)
            
    # calculate the metrics for the whole timetable
    df_metrics = pd.DataFrame(vehicle_reports)
    VMT = df_metrics['VMT'].sum()
    PMT = df_metrics['PMT'].sum()
    VDM = df_metrics['VDM'].sum()
    number_of_passengers_served = df_metrics['number_of_passengers_served'].sum()
    number_of_shared_rides = df_metrics['number_of_shared_rides'].sum()
    total_number_of_requests = len(dfr)
    timetable_report = {
        'VMT': VMT,
        'PMT': PMT,
        'VMT_PMT_Ratio': VMT / PMT,
        'VDM': VDM,
        'number_of_passengers_served': number_of_passengers_served,
        'total_number_of_requests': total_number_of_requests,
        'number_of_shared_rides': number_of_shared_rides,
        'Shared_Rate': int((number_of_shared_rides / number_of_passengers_served) * 100),
        'Service_Rate': int((number_of_passengers_served / total_number_of_requests) * 100)
    }
    
    result = {
        'timetable_report': timetable_report,
        'vehicle_reports': vehicle_reports
    }
    return result

# %% [markdown]
# ### Get Metrics

# %%
df = pd.DataFrame(manifests)
result = timetable_report(df,payload)
result
# Out:
# {'timetable_report': {'VMT': 1306.161591050342,
#   'PMT': 951.1640770665009,
#   'VMT_PMT_Ratio': 1.37322426544818,
#   'VDM': 756.994406463642,
#   'number_of_passengers_served': 169,
#   'total_number_of_requests': 169,
#   'number_of_shared_rides': 97,
#   'Shared_Rate': 57,
#   'Service_Rate': 100},
#  'vehicle_reports': [{'VMT': 113.69732753262896,
#    'PMT': 84.40459912989435,
#    'VMT_PMT_Ratio': 1.3470513301965288,
#    'VDM': 65.68489745183344,
#    'number_of_passengers_served': 17,
#    'number_of_shared_rides': 12,
#    'Shared_Rate': 70,
#    'run_id': 0},
#   {'VMT': 62.778123057799874,
#    'PMT': 46.300807955251706,
#    'VMT_PMT_Ratio': 1.3558753255120943,
#    'VDM': 36.59850839030454,
#    'number_of_passengers_served': 10,
#    'number_of_shared_rides': 8,
#    'Shared_Rate': 80,
#    'run_id': 1},
#   {'VMT': 79.64822871348663,
#    'PMT': 67.05096333126166,
#    'VMT_PMT_Ratio': 1.187875979051768,
#    'VDM': 41.56619018023617,
#    'number_of_passengers_served': 10,
#    'number_of_shared_rides': 6,
#    'Shared_Rate': 60,
#    'run_id': 2},
#   {'VMT': 86.77812305779987,
#    'PMT': 58.26413921690491,
#    'VMT_PMT_Ratio': 1.489391660533137,
#    'VDM': 65.79676817899316,
#    'number_of_passengers_served': 7,
#    'number_of_shared_rides': 2,
#    'Shared_Rate': 28,
#    'run_id': 3},
#   {'VMT': 43.9372280919826,
#    'PMT': 27.362958359229335,
#    'VMT_PMT_Ratio': 1.6057192177527426,
#    'VDM': 24.082038533250465,
#    'number_of_passengers_served': 11,
#    'number_of_shared_rides': 7,
#    'Shared_Rate': 63,
#    'run_id': 4},
#   {'VMT': 115.48912367930392,
#    'PMT': 97.62709757613425,
#    'VMT_PMT_Ratio': 1.1829617651927018,
#    'VDM': 56.57613424487259,
#    'number_of_passengers_served': 14,
#    'number_of_shared_rides': 8,
#    'Shared_Rate': 57,
#    'run_id': 5},
#   {'VMT': 137.1932877563704,
#    'PMT': 104.15786202610317,
#    'VMT_PMT_Ratio': 1.3171668953994866,
#    'VDM': 70.44002486016159,
#    'number_of_passengers_served': 21,
#    'number_of_shared_rides': 16,
#    'Shared_Rate': 76,
#    'run_id': 6},
#   {'VMT': 91.911124922312,
#    'PMT': 65.9552517091361,
#    'VMT_PMT_Ratio': 1.393537626505343,
#    'VDM': 64.98756991920447,
#    'number_of_passengers_served': 11,
#    'number_of_shared_rides': 6,
#    'Shared_Rate': 54,
#    'run_id': 7},
#   {'VMT': 141.67930391547546,
#    'PMT': 107.80919825978869,
#    'VMT_PMT_Ratio': 1.3141671230507597,
#    'VDM': 83.9160969546302,
#    'number_of_passengers_served': 18,
#    'number_of_shared_rides': 8,
#    'Shared_Rate': 44,
#    'run_id': 8},
#   {'VMT': 156.89683032939715,
#    'PMT': 105.06712243629583,
#    'VMT_PMT_Ratio': 1.4933009174637542,
#    'VDM': 81.51771286513362,
#    'number_of_passengers_served': 18,
#    'number_of_shared_rides': 13,
#    'Shared_Rate': 72,
#    'run_id': 9},
#   {'VMT': 97.53200745804848,
#    'PMT': 64.34493474207582,
#    'VMT_PMT_Ratio': 1.5157682240102,
#    'VDM': 52.39465506525792,
#    'number_of_passengers_served': 8,
#    'number_of_shared_rides': 3,
#    'Shared_Rate': 37,
#    'run_id': 10},
#   {'VMT': 67.3088875077688,
#    'PMT': 29.929148539465505,
#    'VMT_PMT_Ratio': 2.248940941938699,
#    'VDM': 46.37103791174643,
#    'number_of_passengers_served': 9,
#    'number_of_shared_rides': 1,
#    'Shared_Rate': 11,
#    'run_id': 11},
#   {'VMT': 111.31199502796768,
#    'PMT': 92.8899937849596,
#    'VMT_PMT_Ratio': 1.1983206209019135,
#    'VDM': 67.0627719080174,
#    'number_of_passengers_served': 15,
#    'number_of_shared_rides': 7,
#    'Shared_Rate': 46,
#    'run_id': 12},
#   {'VMT': 0,
#    'PMT': 0,
#    'VMT_PMT_Ratio': 0,
#    'VDM': 0,
#    'number_of_passengers_served': 0,
#    'number_of_shared_rides': 0,
#    'Shared_Rate': 0,
#    'run_id': 13},
#   {'VMT': 0,
#    'PMT': 0,
#    'VMT_PMT_Ratio': 0,
#    'VDM': 0,
#    'number_of_passengers_served': 0,
#    'number_of_shared_rides': 0,
#    'Shared_Rate': 0,
#    'run_id': 14},
#   {'VMT': 0,
#    'PMT': 0,
#    'VMT_PMT_Ratio': 0,
#    'VDM': 0,
#    'number_of_passengers_served': 0,
#    'number_of_shared_rides': 0,
#    'Shared_Rate': 0,
#    'run_id': 15},
#   {'VMT': 0,
#    'PMT': 0,
#    'VMT_PMT_Ratio': 0,
#    'VDM': 0,
#    'number_of_passengers_served': 0,
#    'number_of_shared_rides': 0,
#    'Shared_Rate': 0,
#    'run_id': 16},
#   {'VMT': 0,
#    'PMT': 0,
#    'VMT_PMT_Ratio': 0,
#    'VDM': 0,
#    'number_of_passengers_served': 0,
#    'number_of_shared_rides': 0,
#    'Shared_Rate': 0,
#    'run_id': 17}]}
